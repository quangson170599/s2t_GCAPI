# %%
# !pip install google-cloud-speech
# !pip install google-cloud-storage
# !pip install pydub
# !pip install speechbrain
# !pip install pyannote.audio==2.0.1
# !pip install pyannote.core
# !pip install underthesea

# %%
## Library
import os
from pydub import AudioSegment, silence
import wave
from google.cloud import speech
from google.cloud import storage
from concurrent.futures import ThreadPoolExecutor
import io

from pyannote.audio import Pipeline

pipeline = Pipeline.from_pretrained("pyannote/speaker-diarization")

os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'Speech2Text.json'

## Tạo thư mục cho từng tác vụ
Thu_muc_cho_audio_cat_theo_giong_noi = 'Splited_speaker'
Thu_muc_cho_audio_cat_theo_silence   = 'Splited_Silence'

os.makedirs(Thu_muc_cho_audio_cat_theo_giong_noi ,exist_ok= True)
os.makedirs(Thu_muc_cho_audio_cat_theo_silence   ,exist_ok= True)
# Out:
# c:\Users\stech-data\anaconda3\envs\s2t_GCP_GPU\lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)
# The torchaudio backend is switched to 'soundfile'. Note that 'sox_io' is not supported on Windows.
# The torchaudio backend is switched to 'soundfile'. Note that 'sox_io' is not supported on Windows.

# %%
# Split Speaker
def Split_speaker(audio_file):
    Audio = AudioSegment.from_file(audio_file)
    name = Thu_muc_cho_audio_cat_theo_giong_noi + '/' + audio_file.split('/')[-1].replace('.wav', '')

    os.makedirs(name, exist_ok=True)
    hashDict = dict()
    diarization = pipeline(audio_file)
    
    i,start,end,lab = 0,0,0,0
    for segment,track,label in diarization.itertracks(yield_label = True):
        if label != lab:
            Audio_speaker_i = Audio[start * 1000 : end * 1000]
            Audio_speaker_i.export(name + '/' + str(i) + '.wav', format = 'wav')
            hashDict[name + '/' +str(i) + '.wav'] = lab
            i += 1
            start = segment.start
            end = segment.end
            lab = label
        elif label == lab:
            end = segment.end
    # chạy vòng cuối
    Audio_speaker_i = Audio[start * 1000 : end * 1000]
    Audio_speaker_i.export(name +'/' + str(i) + '.wav', format = 'wav')
    hashDict[name + '/' +str(i) + '.wav'] = lab
    
    os.remove(name + '/' + str(0) + '.wav')
    hashDict.pop(name + '/' +str(0) + '.wav')
    return hashDict

# %%
# Split Silence
def export_audio(audio, count,name):
    audios = audio.set_frame_rate(16000)
    audios.export(os.path.join(name + '/file_{}.wav'.format(str(count))), format='wav')

# hashDict: {speaker: (start, stop)}
def split_silence(audio, speaker):
    folder = Thu_muc_cho_audio_cat_theo_silence
    os.makedirs(folder, exist_ok=True)
    name = audio.split('/')
    name = name[-2] + "/" + name[-1].replace('.wav','')
    name = os.path.join(folder,name)
    os.makedirs(name, exist_ok=True)

    myaudio = AudioSegment.from_file(audio, "wav")
    dbfs = myaudio.dBFS
    duration_in_sec = len(myaudio) / 1000

    mydict = dict()
    t_dict = dict()

    # Lấy các khoảng silence trong audio
    silences = silence.detect_silence(myaudio,
                                      min_silence_len= 300,
                                      silence_thresh=dbfs-10)
    silences = [((start/1000),(stop/1000)) for start,stop in silences]
    # print(silences)

    if len(silences) > 0:
        n_silence = []
        if silences[0][0] == 0.0:
            n_silence.append(silences[0])
            silences.pop(0)

        # Chỉnh lại, làm tròn sec
        for i in silences:
            if round(i[0]) < i[0]:
                temp= (i[0]+0.5, i[1])
            else:
                temp= (round(i[0]), i[1])
            n_silence.append(temp)
        

        count = 1
        for start,end in silences:
            temp= name+'/file_'+str(count)+'.wav' # vị trí file: lưu file ở thư mục nào thì địa chỉ tới thư mục đó
            t_dict[temp]= end-start
            count +=1
        

        start = 0.0
        end = duration_in_sec
        s_audio = myaudio[start*1000:n_silence[0][0]*1000]
        export_audio(s_audio, 1,name)
        count = 2
        for i in range(len(n_silence)-1):
            s= n_silence[i][1]
            e= n_silence[i+1][0]
            n_audio = myaudio[s*1000:e*1000]
            export_audio(n_audio, count,name)
            count += 1
        if n_silence[len(n_silence)-1][1] != end:
            e_audio = myaudio[n_silence[len(n_silence)-1][1]*1000:end*1000]
            export_audio(e_audio, count,name)
            temp= name + '/file_'+str(count)+'.wav'
            t_dict[temp] = 0
    else:
        temp= name+'/file_'+str(0)+'.wav'
        export_audio(myaudio, 0,name)
        t_dict[temp] = 0
    mydict[speaker] = t_dict
    return mydict

# %%
# tổng hợp bucket hiện có
def list_buckets():
    """Lists all buckets."""

    storage_client = storage.Client()
    buckets = storage_client.list_buckets()

    for bucket in buckets:
        print(bucket.name)

def upload_blob(bucket_name, source_file_name, destination_blob_name):
    """Uploads a file to the bucket."""
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(destination_blob_name)

    blob.upload_from_filename(source_file_name)

    print(
        f"File {source_file_name} uploaded to {destination_blob_name}."
    )

# %%
# Một số Function hỗ trợ xử lý văn bản đầu ra
def is_digit(word):
    try:
        int(word)
        return True
    except ValueError:
        pass
    return False


def ConvertDate(text):
    month=' tháng '
    year=' năm '
    for index in range(0,len(text)):
        try:
            if (text.index(month,index)==index):
                dateNum = text[index -1]
                monthNum = text[index + len(month)]
                if is_digit(dateNum) and is_digit(monthNum):
                    text=text[:index] + text[index+len(month)-1:]
                    temp = list(text)
                    temp[index]='/'
                    text = "".join(temp)
        except Exception as e:
            if str(e) in 'substring not found':
                pass
            else:
                raise e
        try:
            if (text.index(year,index)==index):
                monthNum = text[index -1]
                yearNum = text[index + len(year)]
                if is_digit(monthNum) and is_digit(yearNum):
                    text=text[:index] + text[index+len(year)-1:]
                    temp = list(text)
                    temp[index]='/'
                    text = "".join(temp)
        except Exception as e:
            if str(e) in 'substring not found':
                pass
            else:
                raise e
    return text

# %%
# Các Function xử dụng GCP API thực hiện speech to text
def frame_rate_channel(audio_file_name):
    print(audio_file_name)
    with wave.open(audio_file_name, "rb") as wave_file:
        frame_rate = wave_file.getframerate()
        channels = wave_file.getnchannels()
        return frame_rate,channels

## Config_GGC_model_before_Transcribe
def Config_GGC(sample_rate_hertz = 44100,
                audio_channel_count = 1):
        config_wav_enhanced = speech.RecognitionConfig(
            sample_rate_hertz = sample_rate_hertz,
            language_code = 'vi-VN',
            audio_channel_count=audio_channel_count,
        )
        
        return config_wav_enhanced



def Transcribe_Short_Audio(Audio_wav,config_wav_enhanced):
    client = speech.SpeechClient()
    with io.open(Audio_wav, "rb") as audio_file:
        content = audio_file.read()

    audio = speech.RecognitionAudio(content=content)
    # print(type(audio))
    
    response = client.recognize(config=config_wav_enhanced, audio=audio)
    text = []
    for i, result in enumerate(response.results):
        alternative = result.alternatives[0]
        alter=ConvertDate(alternative.transcript+ '\n')
        text.append(alter)
    return text

### This function is main on stranscribe
def Transcribe_Long_Audio(Audio_wav,config_wav_enhanced,
                        bucket_name = 'speech_to_text_stech',
                        Name = 'Audio_wav'):
    client = speech.SpeechClient()
    Audio_name = Audio_wav.split('/')[-1].split('.')[0]
    
    upload_blob(bucket_name,Audio_wav,Name)
    
    media_uri = "gs://{}/{}".format(bucket_name,Name)
    long_audi_wav = speech.RecognitionAudio(uri=media_uri)
    
    
    operations = client.long_running_recognize(
        config = config_wav_enhanced,
        audio = long_audi_wav
    )
    
    response = operations.result(timeout=90)

    text = []
    
    for i, result in enumerate(response.results):
            alternative = result.alternatives[0]
            alter=ConvertDate(alternative.transcript)
            text.append(alter)
    return text

# %%
##Take audio to text+punc
def AudioToText(path,config):
    try:
        text=Transcribe_Short_Audio(path,config)
    except:
        text = Transcribe_Long_Audio(path,config)
    return text

# %%
# Sử dụng Google API để dịch từng Audio sang text

def GCP_s2t(alist):
    index=list(alist[0])[0]
    sample_file_config=list(alist[0][index])[0]
    
    rate,channel=frame_rate_channel(sample_file_config)
    config = Config_GGC(sample_rate_hertz = rate,
                 audio_channel_count = channel)
    def thread_function(index,file_addr):
        text=AudioToText(file_addr,config)
        x = index,text
        return x
    def func_sort(e):
        return e[0]
    result_dict = {'Speaker':[], 'co dau':[],'khong dau':[],'silence':[]}
    for adict in alist:
        for speaker,value in adict.items():
                file_addr = list(adict[speaker].keys())
                silent_time = list(adict[speaker].values())
                index = list(range(len(file_addr)))
                with ThreadPoolExecutor(8) as executor:
                    futures = executor.map(thread_function,index,file_addr)
                    index_text = [x for x in futures] 
                index_text.sort(key=func_sort)
                text = [text for _,text in index_text]
                result_dict['Speaker'].extend([speaker] * len(silent_time))
                result_dict['co dau'].extend(text)
                result_dict['khong dau'].extend(text)
                result_dict['silence'].extend(silent_time)

    return result_dict

# %%
# Function Kết hợp Text có dấu theo Google API và silence

def Handle_Text_Dict(adict,S_Punc_ok=False):
    adict = list(adict.values())
    Spr,SL = 0,0
    ReDict = {'Speaker':[], 'co dau':[],'khong dau':[]}
    Silent_Punc = []
    for Speaker,Punc,NoPunc,Silent in zip(*adict):
        # Vì Punc,NoPunc là list
        new_Punc = str()
        for i in Punc:
            new_Punc += i
        new_NoPunc = str()
        for i in NoPunc:
            new_NoPunc += i
        
        if Speaker != Spr:
            # Làm gì đó
            Spr = Speaker
            SL = Silent
            ReDict['Speaker'].append(Speaker)
            
            ReDict['khong dau'].append(new_NoPunc)
            if S_Punc_ok == True:
                ReDict['co dau'].append(new_NoPunc + '. ')
            else:
                ReDict['co dau'].append(new_Punc)
        else: 
            ReDict['khong dau'][-1] += ' ' + new_NoPunc
            ReDict['co dau'][-1] += ' ' + new_Punc
    return ReDict

# %%
# Phần ghép các Function
Audio_Input = 'Input/hoinghi.wav'

# Đưa các lệnh dưới đây của cell này vô Function là ta có Pipeline

# splited speaker
hashDict = Split_speaker(Audio_Input)

# splited Silence
My_info = []
for audio,speaker in hashDict.items():
    my_dict = split_silence(audio,speaker)
    My_info.append(my_dict)

# %%
# Chuyển từng audio thành text có dấu và không dấu
Text_Dict=GCP_s2t(My_info)

# Chuyển thành Dict theo yêu cầu của Tín và để cho phần tìm silent
Result = Handle_Text_Dict(Text_Dict)
Result2 = Handle_Text_Dict(Text_Dict,S_Punc_ok=True)
# Out:
# Splited_Silence\hoinghi/1/file_1.wav

# %%
from underthesea import pos_tag as pot
import re

def add_punc(final, final_with_punc):
    x = final
    y = final_with_punc
    new = []
    for i in range(len(x)):
        if ':' in x[i]:
            t = x[i].split(':')[1].strip()
            new.append(x[i].replace(t, y[i]))
        else:
            new.append(y[i])
    return new


def recognize(conser):

    def capital(noun):
        return ' '.join([str(wordx).capitalize() for wordx in noun.split()])

    final = conser
    military_rank = ['đại tướng', 'trung tướng', 'thiếu tướng', 'đại tá','thượng tá', 'trung tá', 'thiếu tá', 'đại úy', 'thượng úy', 'trung úy', 'thiếu úy']
    start_para = [ 'xin trân trọng kính','tôi xin kính','xin kính','tôi xin', 'xin', 'kính','tôi']
    vocative = ['đồng chí', 'đại biểu']
    checkpoint_start = ['phát biểu','đặt câu hỏi','trả lời','cho ý kiến','nêu ý kiến']
    end_para = ['tôi xin báo cáo hết', 'xin phép báo cáo hết' ,'xin báo cáo hết'
               , 'xin phép hết','báo cáo hết','tôi xin hết', 'xin hết']
    thank_full = ['tôi xin cảm ơn','tôi cảm ơn','cảm ơn']
    end_co=[]
    for i in end_para:
        for j in thank_full:
            end = i+' '+j
            end_co.append(end)

    pos = pot(final)
    #nhận diện chỉ tử mời
    for i, (wor, tag) in enumerate(pos):
        if wor == 'mời' and i != len(pos)-1 and i != 0:
            if pos[i+1][0] in vocative and str(pos[i-1][0]).lower() not in start_para:
                original = pos[i-1][0] + ' mời'
                subtitute = pos[i-1][0] + ' xin mời'
                final = final.replace( original, subtitute)
            elif pos[i+1][0] in military_rank and str(pos[i-1][0]).lower() not in start_para:
                original = pos[i-1][0] + ' mời ' + pos[i+1][0]
                subtitute = pos[i-1][0] + ' xin mời đồng chí'
                final = final.replace(original, subtitute)
    words = []
    tags = []
    # Thay thế tất cả start bằng xin_mời
    for start in start_para:
        find = re.compile(start+' mời')
        for m in find.finditer(final.lower()):
            sta_in , end_in = m.start(), m.end()
            final = final[0:sta_in] + 'xin_mời' + final[end_in:]
    #Thay thế các end_co bằng báo cáo hết
    for end in end_co:
        find = re.compile(end)
        for m in find.finditer(final.lower()):
            sta_in, end_in = m.start(), m.end()
            final = final[0:sta_in] + 'báo_cáo_hết' + final[end_in:]
    #Thay thế tất cả end bằng báo_cáo_hết
    for end in end_para:
        find = re.compile(end)
        for m in find.finditer(final.lower()):
            sta_in, end_in = m.start(), m.end()
            final = final[0:sta_in] + 'báo_cáo_hết' + final[end_in:]


    # Lưu từ và phân loại vào list words, tags
    postag = pot(final)
    for text, tag in postag:
        words.append(text)
        tags.append(tag)
    # Xử lý văn bản
    for i, word in enumerate(words):
        # Xét trường hợp không phải những từ cuối câu
        if i != len(words)-1 and i != len(words)-2:
            # xét từ đồng chí và không có rank
            if word in vocative and words[i+1].lower() not in military_rank:
                # từ liền trước là xin mời
                if words[i-1] == 'xin_mời':
                    # nếu từ liền sau là N hoặc Np
                    if tags[i+1] in ['N', 'Np', 'V'] or len(words[i+1]) > 5:
                        print( 'MĐ: xin mời k có rank '+ words[i+1] + ' TH1' )
                        ori_sta = 'xin_mời '+word+' '+ words[i+1]
                        sub_sta = '==Đồng chí ' + capital(words[i+1]) + ': '
                        final = final.replace(ori_sta, ori_sta + sub_sta)
                    # nếu từ liền sau tiếp là N hoặc Np
                    elif tags[i+2] in ['N', 'Np', 'V']  or len(words[i+2]) > 5:
                        print( 'MĐ: xin mời k có rank '+ words[i+1] + ' TH2' )
                        ori_sta = 'xin_mời '+word+' '+ str(words[i+1]) + ' ' + words[i+2]
                        sub_sta = '==Đồng chí ' + capital(words[i+1]) + ' ' + words[i+2] +':'
                        final = final.replace(ori_sta, ori_sta + sub_sta)
            # xét từ rank
            if word in vocative and words[i+1].lower() in military_rank:
                if words[i-1] == 'xin_mời':
                    # nếu từ liền sau là N hoặc Np
                    if tags[i+2] in ['N','Np','V'] or len(words[i+2]) > 5:
                        print( 'MĐ: xin mời '+ words[i+1] + ' TH1' )
                        ori_sta = 'xin_mời '+word+' '+ words[i+1] + ' ' + words[i+2]
                        sub_sta = '=='  + str(words[i+1]) + ' ' + capital(words[i+2]) + ': '
                        final = final.replace(ori_sta, ori_sta + sub_sta)
                    # nếu từ liền sau tiếp là N hoặc Np
                    elif tags[i+3] == 'N' or tags[i+3] == 'Np'  or len(words[i+3]) > 5:
                        print( 'MĐ: xin mời '+ words[i+1] + ' TH2' )
                        ori_sta = 'xin_mời '+word+' '+ words[i+1] +' ' + str(words[i+2]) + ' ' + words[i+3]
                        sub_sta = '==' + words[i+1] + ' ' + capital(words[i+2]) + ' ' + capital(words[i+3]) +':'
                        final = final.replace(ori_sta, ori_sta + sub_sta)
            if word in military_rank:
                if words[i-1] == 'xin_mời':
                    if tags[i+1] in ['N','Np','V'] or len(words[i+1]) > 5:
                        print('MĐ không có từ đồng chí TH1')
                        ori_sta = 'xin_mời '+word+' '+ words[i+1]
                        sub_sta = '=='+ word + ' ' + capital(words[i+1])+': '
                        final = final.replace(ori_sta, ori_sta + sub_sta)
                    # nếu từ liền sau tiếp là N hoặc Np
                    elif tags[i+2] == 'N' or tags[i+2] == 'Np'  or len(words[i+2]) > 5:
                        print('MĐ không có từ đồng chí TH1')
                        ori_sta = 'xin_mời '+word+' '+ words[i+1] +' ' + str(words[i+2])
                        sub_sta = '==' + capital(words[i+1]) + ' ' + capital(words[i+2]) + ':'
                        final = final.replace(ori_sta, ori_sta + sub_sta)

    final = final.replace('báo_cáo_hết','==')
    final = final.replace('xin_mời','xin mời')
    for check in checkpoint_start:
        find = re.compile(': '+ check)
        for m in find.finditer(final.lower()):
            sta_in, end_in = m.start(), m.end()
            final = final[0:sta_in] + ': cho_ý_kiến' + final[end_in:]
    final = final.replace(': cho_ý_kiến', ':')

    paragraph =[para.strip() for para in final.split('==')]
    return paragraph

# input_1 with file json
def process_input(input_1):
    text_no_punc = input_1['khong dau']
    text_punc = input_1['co dau']
    text_done = []
    index_replace = []
    text_process = '/n '.join(text_no_punc)
    #print(text_process)
    text_reg = recognize(text_process)
    for text in text_reg:
        if '/n ' in text:
            a = text.split('/n ')
            for para in a:
                text_done.append(para)
        if '/n ' not in text:
            text_done.append(text)
    for i in range(len(text_done)):
        if ':' in text_done[i] and text_done[i] != len(text_done)-1:
            x = text_done[i] + ' ' + text_done[i+1]
            index_replace.append(i+1)
            text_done[i] = x
    minus = 0
    for i in index_replace:
        i -= minus
        del text_done[i]
        minus += 1
    # for i in range(len(text_done)-1):
    #     if text_done[i] == '':
    #         del text_done[i]
    while '' in text_done:
        text_done.remove('')
    print(len(text_done), len(text_punc))
    if len(text_done) == len(text_punc):
        final_text = add_punc(text_done, text_punc)
        a = 'Success'
    else:
        final_text = text_done
        a = 'Fail'
    return a , final_text

# %%
output,final_text=process_input(Result)
# Out:
# MĐ: xin mời k có rank Trần Thanh Mẫn viên TH1
# 43 52

# %%
final_text
# Out:
# ['chị và các bạn cùng theo dõi bản tin trực tiếp\n ngày khai mạc\n Quốc hội\n chị và các bạn\n nay ngày\n tháng 5/2000\n 22\n tại hội trường Diên Hồng\n họp thứ 3 Quốc hội khóa\n khai mạc\n học Thứ ba là kỹ thuật trực tiếp dài nhất kể từ đầu\n về đến nhà\n Khi dịch bệnh của thiết bị chính đã cơm\n  có đường cong\n Nội dung quan trọng\n ngày dự báo sẽ thu hút được sự chú ý\n hồng lớn của nhân dân cả nước\n ca khúc là bởi vì dù trị bệnh đã được kiểm soát\n những tác động của\n vẫn khiến cho việc sản xuất kinh doanh của nhiều ngành nghề\n đời sống của người dân\n dịch bệnh vẫn còn\n khó khăn\n mức việc làm\n Bên cạnh đó thì hàng loạt các vụ án có liên quan đến thao túng thị trường chứng khoán\n em hiểu Phát hành trái phiếu\n tác động không nhỏ đến thị trường\n mất niềm tin cho nhà đầu tư\n kết quả tham nhũng hối lộ liên quan đến cầu tiền tệ\n bức xúc trong dư luận xã hội\n những vấn đề trọng tâm sẽ được thảo luận tại\n  Cái đó thì quốc hội sẽ dành thời gian để thảo luận\n kế hoạch phát triển kinh tế xã hội\n   tư vấn và trả lời chất vấn của đại biểu Quốc hội\n biết là thảo luận giải pháp\n đất nước vượt qua giai đoạn\n  YouTube\n  trước giờ khai mạc kỳ họp thứ 3 Quốc hội khóa 15\n cách để biểu Quốc hội\n học tập\n nhà quốc hội thủ đô Hà Nội\n Đặt vòng hoa\n vào lăng viếng\n  lễ viếng có chủ tịch nước Nguyễn Xí\n Thủ tướng Chính phủ Phạm Minh Chính\n chủ tịch quốc hội Vương Đình Huệ\n cùng các vị đại biểu Quốc hội\n hoa của Đoàn dòng chữ Đời đời nhớ ơn Chủ tịch Hồ Chí Minh vĩ đại\n bị lãnh đạo Đảng Nhà nước\n kính cận như mình\n tỏ lòng thành kính trước anh linh Chủ Tịch Hồ Chí Minh nước của dân tộc Việt Nam tưởng nhớ công lao vĩ đại của người đối với sự nghiệp đấu tranh giải phóng dân tộc trên nền độc lập tự do của tổ quốc\n hạnh phúc của nhân dân kết thúc lễ viếng các đại biểu trở về nhà quốc hội và tham dự lễ khai mạc kỳ họp thứ 3 Quốc hội khóa 15\n lúc 9 giờ sáng cùng ngày tại phòng làm việc học\n Quốc hội của thủ
#  '66% số doanh nghiệp tham gia khảo sát của chúng tôi\n  trong quý 2\n chỉ 52% của quý 4 năm ngoái hơn 46% doanh nghiệp Châu Âu\n đúng dự định\n thêm nhân viên trong quý tới\n dấu hiệu phục hồi\n',
#  ' tổ chức quốc tế cũng đã điều chỉnh dự báo tăng trưởng của Việt Nam năm 2022\n con số này\n ngân hàng standard chartered\n làm mất 6,7%\n  ổn định của khu vực sản xuất\n yêu cầu nội địa và du lịch phục vụ\n được xem là động lực mới\n mức dự báo tăng trưởng khả quan\n tôi hết sức lạc quan với triển vọng tăng\n  đó là việc Chính phủ đã gỡ bỏ quy định về cách ly cho các quốc tế đến Việt Nam\n  chúng tôi cho rằng\n mở cửa vốn góp 10%\n  quan sát\n sắc sảo trong quý 2 năm nay\n 25\n   nghị quyết của chính phủ đặt mục tiêu Việt Nam tăng trưởng từ 6 đến 6,5% trong năm\n thông báo kết luận của ủy ban thường vụ quốc hội về kế hoạch kinh tế xã hội và ngân sách 2020 hay chỉ rõ\n  6 đến 6,5% theo nghị quyết 30a\n tăng thêm 2%\n tác động của chính sách tài khóa tiền tệ\n phục hồi và phát triển kinh tế xã\n  bán hàng những giải pháp phù hợp\n tạo đạt được mục\n',
#  'không chỉ có kinh tế mà giáo dục cũng là một vấn đề rất đáng quan tâm vào\n tăng ca bằng lượng tại kỳ\n  kỳ họp thứ 3 diễn ra theo ủy ban thường vụ quốc hội cũng đã đề nghị\n có đánh chết cụ thể công tác chỉ đạo thực hiện đổi mới chương trình sách giáo khoa Giáo dục\n báo cáo về kinh tế xã hội để đại biểu quốc hội thảo\n đáng chú ý là vị trí luận xã hội còn băn khoăn\n có những ý kiến trái chiều về việc chương 4 lịch sử là một hộp tự chọn ở mặt Trung học phổ\n có thể xảy ra hậu quả và hệ lụy khó lường\n xem xét của các\n đánh giá khách quan toàn diện\n chương trình cải cách giáo dục phổ thông\n là việc đưa môn lịch sử ở bậc trung học phổ\n học từ\n ngày hôm qua ngày 22/05\n văn hóa giáo dục của Quốc hội cũng đã tổ chức phiên họp toàn thể lần\n Báo cáo việc triển khai chương trình giáo dục phổ thông\n đối với môn lịch sử bậc trung học phổ thông\n chính thức đề nghị\n lịch sử Đảng\n  ',
#  ' bộ phim\n  kế hoạch từ năm học 2020 2023 tới đây\n thực hiện theo chương trình giáo dục phổ thông mới\n',
#  'kế hoạch\n',
#  'môn lịch sử sẽ là môn tự chọn đối với học sinh Trung học phổ thông bắt đầu với học sinh\n này đang trở thành tâm điểm của Dư luận với nhiều ý kiến trái chiều\n xã hội em không có nhiều tiền em không có dễ học thuộc bài nhưng mà Nên là chắc chắn em sẽ chọn các số tự nhiên có thành phần một tự nhiên để các bạn tổ trưởng là sẽ coi thường các môn ví dụ như là hai văn học là nó chị So lại những môn học thuộc và nó sẽ không giúp ích được gì cho cuộc sống của chúng ta sau này hết chung là nó không phải để làm ấy không học bài Nhưng mà
#  'ngày 29/3 cơ quan cảnh sát điều tra đã tiến hành khởi tố bắt tạm giam ông Trịnh Văn Quyết\n tập đoàn FLC với tội danh\n thị trường chứng khoán\n điều 211 bộ luật\n ông Đỗ Anh Dũng chủ tịch hội đồng quản trị tập đoàn Tân Hoàng Minh\n người có liên quan bị bắt\n để điều tra về tội lừa đảo chiếm đoạt tài sản\n ngày 20/04 Cơ quan Cảnh sát điều tra Bộ Công an tiếp tục khởi tố bắt tạm giam ông Đỗ Thành\n Chủ tịch Nước Hữu Tình\n tổng giám đốc chứng khoán Trí Việt\n điều tra về tội thao túng thị trường chứng khoán\n  tổ chức cá nhân vi phạm nghiêm trọng phải xử\n',
#  'nhanh chóng\n      lợi ích hợp pháp\n      phát triển nhanh\n            doanh nghiệp\n   ',
#  'ngày 20/5 bộ tài chính đã cách chức Chủ tịch Ủy ban Chứng khoán Nhà nước Trần\n vi phạm khuyết điểm nghiêm trọng trong các tầng\n đối với ông Vũ Bằng\n bí thư Đảng ủy cơ quan ủy ban Chứng khoán Nhà nước\n đoạn 2015 2020\n Nguyễn Thành Long chủ tịch hội đồng thành viên sở giao dịch chứng khoán Việt Nam và ông Nguyễn Sơn chủ tịch hội đồng quản trị trung tâm lưu ký chứng khoán Việt Nam sau đã có vi phạm khuyết điểm trong\n ủy ban kiểm tra trung ương đã có kết luận về sai phạm của các nhân sự này thậm chí ông Lê Hải Trà tổng giám đốc khác với bị khai trừ khỏi\n',
#  '  món chay chính sách móng tay trong cái việc là tại Tổ\n mạng mạng Hỏa\n  chính\n  tạo ra một cái sự phát triển bền vững hơn cho thí sinh\n và khắc phục\n      phòng xuất\n một thời gian dài vừa qua trên thị trường tài chính\n   hướng tới\n  Tài chính phát triển\n và cái\n  ',
#  'trường Đồng thời thì nó mở ra\n khả năng lượng\n  ngân hàng\n   cho tôi thì thị trường sau khi đã trải qua 6 tuần để chỉnh sửa\n   thông tin\n có thể là\n   liên quan đến những việc cán bộ chủ chốt\n liên quan đến doanh nghiệp\n Tết được khi vào thị trường chúng ta muốn vươn lên những thị trường mới nổi\n thông tin được\n nhà tư\n   như là nhà được có chống nước\n lấy lại niềm tin\n   những thông tin như vậy\n    ',
#  'tin tức nhà lãnh đạo ngành chứng khoán bị kỷ luật cách chức công nhận được sự đồng tình trong giới đầu tư\n đầu giải ngân\n bắt đi thì thị trường lại xanh\n Tại sao hệ thống cung cấp của Thái Lan Thành ra từ năm 2003 đến gần đây vẫn chưa dùng\n giờ thì có câu trả lời rồi nhé\n nhiều vậy\n có thằng luật quyết định kỷ luật\n thị trường chứng khoán tuần từ 16 đến 20/5\n   mức 1240,71\n luật cổ phiếu danh bạ\n  thời điểm bắt cóc chủ tịch\n',
#  'trong dự thảo báo cáo tóm tắt tổng hợp ý kiến kiến nghị của cử tri và nhân dân\n gửi đến kỳ họp thứ 3 Quốc hội khóa 10\n ủy ban mặt trận\n nhạc chờ\n vẫn còn nhiều tồn tại bất cập về nguồn lực đất đai\n tự chế thu hồi đất bàn giao và thực hiện dự án cấp giấy chứng nhận quyền sử dụng đất\n đó thì cơ quan này cũng đã kiến nghị Đảng và nhà nước cần phải quan tâm giải quyết hiệu quả hơn nữa\n từ khiếu nại\n đặc biệt là về lĩnh vực này\n tớ thì luật đất đai năm 2013 sau gần 10 năm thực hiện\n một rượu nhiều hạn chế yếu kém tồn tại\n đặc biệt là liên quan đến công\n kế hoạch sử dụng đất\n  Thủ Đức\n hỗ trợ bồi\n  hội Đức\n chính sách tài chính đất đai và xác định\n từ đó phát sinh nhiều hệ lụy\n Tổng bí thư Nguyễn Phú Trọng đã nhấn mạnh\n lên giới\n cũng có không ít người nghèo đi\n Đức\n thậm chí bị đi tu cũng bị đứt\n các định nghĩa\n  đồng chí\n  sửa luật đất đai\n bong bóng\n cử chỉ\n',
#  'báo cáo\n  Gọi cho thấy\n trong tháng 4 tình hình khiếu nại tố cáo của người dân tiếp tục gia tăng và diễn biến phức tạp\n tiếp công dân Trung ương đã tiếp hơn 300 lượt công dân với hơn 1000\n nhiều đoàn đông người\n đáng chú ý\n phản ánh của người dân chủ yếu về đất đai\n Căn cứ vào đủ điều kiện\n',
#  ' ',
#  'cho ý kiến báo cáo tổng hợp ý kiến kiến nghị của cử tri và nhân dân gửi đến kỳ họp Quốc hội\n các đại biểu đã đề nghị làm rõ những bức xúc của người dân về đất đai\n  tình trạng người dân khiếu kiện vượt cấp\n lên trung ương\n  không có chiều hướng giảm thời gian gần đây\n                                     đại biểu cũng Đề nghị các cơ quan liên quan phải báo cáo trung thực ý kiến cử tri\n vấn đề trọng tâm\n cũng liên quan đến đất đai\n thực trạng khiếu kiện và bức xúc hiện hữu lâu nay\n cần sớm có lộ trình thích hợp\n toàn diện\n  hợp pháp cho nhà\n',
#  'Chúc quý vị\n báo quốc hội khóa 15\n cùng với thời điểm này giá xăng trong kỳ điều chỉnh ngày hôm nay\n ngày 23/5 được Dự báo có thể tăng khoảng từ 600\n 801\n nhận định này chính xác thì giá xăng trong nước tiếp tục lập được kỷ lục\n 10 đợt điều chỉnh tăng Kể từ đầu năm\n giá xăng Ron 95 có thể vượt mốc 30 ngày là mục đích\n Đây là mức cao nhất từ đầu năm\n cùng với các nguyên liệu đầu vào khác tăng\n yếu tố được xem là cản trở quá trình phục hồi của các ngành\n đại dịch của thiết bị chính\n hỏi phải có giải pháp giúp cho nền kinh tế\n đặt hàng\n ',
#  'từ đầu năm đến\n giá xăng dầu đã có 12 kỳ điều chỉnh có 9 kỳ Giá xăng điều trị\n ba lần điều chỉnh giảm\n đỏ trên mặt hàng xăng Ron 95\n khi điều chỉnh ngày 11/1/2022\n có giá 23870 đồng một lít\n trong phiên điều chỉnh gần nhất ngày 11/05/2022\n mặt hàng này đã là 29980 đồng một lít tương đương với mức tăng 25,5% so với đầu năm\n 53% so với cùng kỳ\n các nguyên vật liệu khác nhưng mà vật liệu nông nghiệp tăng 9,1%\n Chế biến chế tạo tăng 5,52%\n ngành xây dựng tăng 8,26% so với cùng kỳ\n năm nay dự báo lần đầu vượt mốc 4%\n Sau nhiều năm duy trì dưới 4\n năm\n',
#  'năm nay thì\n nó toàn cầu\n   bật điện\n đặc biệt\n  chi phí\n   ở Việt Nam chúng ta là chúng ta không có chế độ chế độ chính\n cũng nhiều\n  chúng tôi nghĩ rằng là năm nay là phát của chúng ta sẽ đẩy lên mức tương đối cao\n dự báo lại mất khoảng là 3,84 = 2\n ',
#  'tổng cục thống kê tính toán\n giá xăng dầu tăng 10\n làm giảm phát tăng 0,36 điểm\n tăng trưởng giảm 0,5 điểm phần trăm\n cách khác\n lạm phát gia tăng do tác động của chi phí giá cả đầu vào tăng\n không chỉ làm ảnh hưởng đến đời sống của người\n lợi nhuận của doanh nghiệp\n ảnh hưởng đến quá trình phục hồi của họ\n',
#  'doanh nghiệp chúng ta cần phải đa dạng hóa nguồn\n vậy chúng ta phải chuẩn bị những nguồn thu nguyên vật liệu\n sản xuất\n giá cả tăng cao\n Chính phủ cần phải có mấy giờ\n có cái giải pháp để làm sao cho giá xăng dầu\n  thế giới\n  giá xăng dầu\n giải pháp mà để cho cái này kinh tế chúng ta không bị tổn thương quá lớn từ khi\n là cái tình trạng là tình trạng của kinh tế ở khu vực\n',
#  'chuyển Chính phủ đã giảm 50% thuế bảo vệ môi trường với xăng dầu từ ngày mùng 1/4 năm nay\n Tuy nhiên sau mức làm này\n chi phí vận chuyển từ 40% trong cơ cấu giá xăng dầu\n đó thuế tiêu thụ đặc biệt là 10%\n nhập khẩu 10%\n giá trị gia tăng 10%\n bảo vệ môi trường 2000₫ 1 lít\n  tính toán để giảm thêm thuế phí vào mặt\n ',
#  'giảm thì sẽ giảm thu của ngân sách\n nhưng mà\n cố gắng\n  sản xuất\n có lẽ cũng phải tính toán tiếp những cái chính sách khác\n quý khách\n ',
#  'được biết hiện Bộ Công Thương đang cùng với Bộ Tài chính nghiên cứu phương án giảm tiếp thuế phí\n đó giảm giá xăng\n và quan trọng của nhiều ngành sản xuất\n doanh nghiệp trong nước chủ động tìm kiếm nguồn cung nguyên phụ liệu thay thế chồng\n nhập khẩu từ bên ngoài\n Vì khi Việt Nam chủ động nguyên liệu\n mới có thể làm chủ được bài toán giá cả\n áp lực tăng\n đó đưa nền kinh tế phục hồi nhanh hơn sau đại dịch covid\n',
#  'có thể đó là có rất nhiều mọi khía cạnh của đời sống xã hội\n quan tâm vậy\n dạ thảo luận\n  bây giờ\n  tuổi phóng viên\n   báo\n chào chị Thanh Tâm\n được biết là luật đất đai sửa đổi được cho ý kiến tại kỳ họp lần này\n Quy Nhơn\n',
#  ' dự án luật đất đai sửa đổi đã bị lỡ hẹn lần thứ Tư Sở dĩ nói như vậy vì theo quyết định của quốc hội thì dự án này\n trong chương trình\n nhưng mà báo cáo trong một phiên họp của ủy ban thường vụ quốc hội diễn ra vào tháng tư vừa qua\n khi cho ý kiến về chương trình xây dựng luật pháp lệnh năm\n điều chỉnh chương trình xây dựng luật pháp lệnh năm 2022\n chính phủ tiếp tục xin lùi dự án vượt qua\
#  '  cảm ơn\n Quốc hội\n tiếp theo chương trình\n trân trọng giới thiệu\n  hướng chính\n  ủy quyền của Thủ tướng Chính phủ\n trình bày báo cáo\n đánh giá bổ sung kết quả thực hiện kế hoạch phát triển kinh tế xã hội\n ngân sách nhà nước năm\n 520\n tình hình thực hiện kế hoạch phát triển kinh tế xã hội và ngân sách nhà\n tháng đầu năm\n 2022\n  Trí Nguyễn\n tổng bí thư\n      Mặt trận Tổ quốc Việt Nam\n các đồng chí Lão thành cách\n   Củ Chi\n  chương trình\n  gửi đến quốc hội\n 26 báo cáo\n   các lĩnh vực\n sự phân công\n Thủ Tướng chính\n  báo cáo Quốc\n một số nội dung chủ\n bổ sung kết quả thực hiện kế hoạch phát triển kinh tế xã hội\n năm 2021\n tình hình thực hiện\n kế hoạch phát triển kinh tế xã hội\n những tháng\n   bổ sung kết quả\n năm 2021\n tình hình thực hiện\n kế hoạch phát triển kinh tế xã hội những tháng đầu năm 2050\n  bổ sung kết quả\n năm 2000\n kỳ họp thứ hai\n    tình hình kinh tế xã hội 9 tháng\n bước thực hiện\n  2021\n tháng cuối năm 2021\n  các cấp các ngành\n các địa phương\n quyết liệt phòng chống dịch covid-19\n  phát triển kinh tế xã hội\n   ban chấp hành Trung ương\n nghị quyết của Quốc hội\n  tình hình\n kinh tế xã hội những tháng cuối năm\n  có nhiều chuyển biến\n   kết quả\n    nhận định\n đánh giá\n Chính phủ đã báo cáo với\n   trên 12 chỉ tiêu chủ\n  vượt kế hoạch\n năm 2020\n một số chỉ tiêu kinh tế xã hội\n công ơn\n báo cáo Quốc hội\n Chỉ số giá tiêu dùng\n api\n bình quân\n 1,84%\n   bội chi ngân sách nhà nước\n    4%\n   thu ngân sách nhà\n  6,8%\n  đặt báo cáo Quốc hội\n  7%\n  kim ngạch xuất khẩu\n 22,6%\n báo cáo Quốc hội\n  17\n  4 tỷ USD\n  nhập tiêu\n 2 tỷ USD\n đạt được nêu trên\n rất đáng trân trọng\n dịch covid-19 bùng phát lần thứ\n nguy hiểm\n lây lan nhanh hơn\n tác động nghiêm trọng\n mọi mặt đời sống của xã hội\n khẳng định\n  cố gắng rất lớn\n toàn hệ thống chính trị\n các cấp\n  các địa phương\n  ngủ ngon\n chung sức đồng lòng\n các tầng lớp nhân dân\n sự giúp đỡ của bạn bè quốc tế\n ở trong thực hiện các nhiệm vụ giải pháp\n  19\n  triển khai kế hoạch phát triển kinh tế xã hội\n những tháng đầu năm\n 2032\n vào năm 2050\n kinh tế thế giới\n dấu hiệu phục hồi\n nhiều quốc gia\n mở cửa\n  các chính sách\n ảnh hưởng của xung đột\n   cùng với những hậu quả\n đại dịch covid-19\n kinh tế thế giới\n hội chợ\n với dự báo trước đó\n ở nhiều nước\n ăn cơm\n  một số hàng hóa quan trọng\n   nền kinh tế được mở cửa\n trạng thái bình thường Mới\n  được kiểm soát\n  phát triển kinh tế xã hội\n các hoạt động văn hóa xã hội\n trở lại bình\n  một số hàng hóa đầu vào\n  giá xăng dầu\n nguồn nhân lực lao động\n lũ lụt cục bộ\n ảnh hưởng đến hoạt động sản xuất kinh\n   Triển khai hiệu quả']
